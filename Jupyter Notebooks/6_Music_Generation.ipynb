# %% [markdown]
# # Replicate - EMOPIA CLS - Music Generation

# %% [markdown]
# [Replicate/EMOPIA](https://replicate.com/annahung31/emopia)

# %%
# !pip install replicate

# %%
from getpass import getpass
import os

REPLICATE_API_TOKEN = getpass()
os.environ["REPLICATE_API_TOKEN"] = REPLICATE_API_TOKEN

# %%
import replicate

output = replicate.run(
    "annahung31/emopia:ad93577dbfe239c7604a49495ac579176157bb2a6f5fa1e0906433fd7acff792",
    input={
        "emotion": "High valence, high arousal"
    }
)
print(output)
# Out:
# https://replicate.delivery/pbxt/s948LqJb3O5fNC6HYvUtdTzyvMEx2r7euTD0ttdLEOotH4TSA/out.mp3
