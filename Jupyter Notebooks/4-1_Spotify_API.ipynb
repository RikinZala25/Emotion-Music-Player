# %% [markdown]
# # Spotify - Search by Emotion Detected

# %% [markdown]
# Q1 as high valence high arousal (HVHA) - Happy,
#
# Q2 as low valence high arousal (LVHA) - Angry,
#
# Q3 as low valence low arousal (LVLA) - Sad,
#
# Q4 as high valence low arousal (HVLA) - Calm.

# %%
# !pip install spotipy

# %%
import json, requests
import numpy as np

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(
    auth_manager=SpotifyClientCredentials(
        client_id='EBMP_APP_CLIENT_ID',
        client_secret='EBMP_CLIENT_SECRET'
        )
    )

# %%
all_genre_seeds = sp.recommendation_genre_seeds()

print(all_genre_seeds)
# Out:
# {'genres': ['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient', 'anime', 'black-metal', 'bluegrass', 'blues', 'bossanova', 'brazil', 'breakbeat', 'british', 'cantopop', 'chicago-house', 'children', 'chill', 'classical', 'club', 'comedy', 'country', 'dance', 'dancehall', 'death-metal', 'deep-house', 'detroit-techno', 'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm', 'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk', 'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove', 'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle', 'heavy-metal', 'hip-hop', 'holidays', 'honky-tonk', 'house', 'idm', 'indian', 'indie', 'indie-pop', 'industrial', 'iranian', 'j-dance', 'j-idol', 'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino', 'malay', 'mandopop', 'metal', 'metal-misc', 'metalcore', 'minimal-techno', 'movies', 'mpb', 'new-age', 'new-release', 'opera', 'pagode', 'party', 'philippines-opm', 'piano', 'pop', 'pop-film', 'post-dubstep', 'power-pop', 'progressive-house', 'psych-rock', 'punk', 'punk-rock', 'r-n-b', 'rainy-day', 'reggae', 'reggaeton', 'road-trip', 'rock', 'rock-n-roll', 'rockabilly', 'romance', 'sad', 'salsa', 'samba', 'sertanejo', 'show-tunes', 'singer-songwriter', 'ska', 'sleep', 'songwriter', 'soul', 'soundtracks', 'spanish', 'study', 'summer', 'swedish', 'synth-pop', 'tango', 'techno', 'trance', 'trip-hop', 'turkish', 'work-out', 'world-music']}

# %%
class EmotionCalculator:
    @staticmethod
    def calculate_angle(arousal, valence):
        # Scale arousal and valence to [-1, 1] range
        arousal_scaled = 2 * arousal - 1
        valence_scaled = 2 * valence - 1
        # Calculate the angle in radians
        angle_rad = np.arctan2(arousal_scaled, valence_scaled)
        # Convert radians to degrees
        angle_deg = np.degrees(angle_rad)
        # Ensure angle is positive
        if angle_deg < 0:
            angle_deg += 360
        return angle_deg

    @staticmethod
    def determine_quadrant(angle_deg):
        if 0 <= angle_deg < 90:
            return "QUAD1"
        elif 90 <= angle_deg < 180:
            return "QUAD2"
        elif 180 <= angle_deg < 270:
            return "QUAD3"
        else:
            return "QUAD4"

    @staticmethod
    def determine_emotion(quadrant_name):
        if quadrant_name == "QUAD1":
            return "Happiness"
        elif quadrant_name == "QUAD2":
            return "Anger"
        elif quadrant_name == "QUAD3":
            return "Sadness"
        else:
            return "Calmness"

# %%
# Calmness
calmness_genres = ['acoustic', 'ambient', 'classical', 'piano', 'relaxation']

# Anger
anger_genres = ['hardcore', 'heavy-metal', 'punk', 'rock', 'grindcore']

# Sadness
sadness_genres = ['blues', 'emotional', 'indie-folk', 'soul', 'sad']

# Happiness
happiness_genres = ['dance', 'disco', 'happy', 'pop', 'reggae']

# %%
res_happy = sp.recommendations(
    seed_genres=happiness_genres,
    limit=30,
    country="US",
    min_energy=0.5,
    max_energy=1.0,
    target_energy=0.8,
    min_valence=0.5,
    max_valence=1.0,
    target_valence=0.8
)

res_sad = sp.recommendations(
    seed_genres=sadness_genres,
    limit=30,
    country="US",
    min_energy=0.1,
    max_energy=0.5,
    target_energy=0.3,
    min_valence=0.1,
    max_valence=0.5,
    target_valence=0.3
)

res_anger = sp.recommendations(
    seed_genres=anger_genres,
    limit=30,
    country="US",
    min_energy=0.5,
    max_energy=1.0,
    target_energy=0.8,
    min_valence=0.1,
    max_valence=0.5,
    target_valence=0.3
)

res_calm = sp.recommendations(
    seed_genres=calmness_genres,
    limit=30,
    country="US",
    min_energy=0.1,
    max_energy=0.5,
    target_energy=0.3,
    min_valence=0.5,
    max_valence=1.0,
    target_valence=0.8
)

# %%
available_markets = ["US", "GB", "DE", "FR", "BR", "JP", "RU", "IN", "KR", "ES"]

def get_preview_url(track_id):
    for market in available_markets:
        try:
            output = sp.track(track_id, market=market)
            if output['preview_url']:
                return output['preview_url']
        except Exception as e:
            print(f"Error occurred: {e}")
    return "No preview url found"

# %%
# Number of limits specified
limit = 30

# List to store track information
track_info_list = []

for i in range(min(limit, len(res_happy["tracks"]))):
    track_info = {}
    track = res_happy["tracks"][i]

    # Extracting track ID and name
    track_info['id'] = track['id']
    track_info['name'] = track['name']

    # Extracting artists' names
    track_info['artists'] = [artist['name'] for artist in track['artists']]

    # Extracting images details
    track_info['images'] = track['album']['images']

    # Extracting preview URL if available
    if 'preview_url' in track and track['preview_url'] is not None:
      track_info['preview_url'] = track['preview_url']
    else:
      track_info['preview_url'] = get_preview_url(track['id'])

    # Extract the track features
    track_features = sp.audio_features(track['id'])
    track_info['arousal'] = track_features[0]['energy']
    track_info['danceability'] = track_features[0]['danceability']
    track_info['acousticness'] = track_features[0]['acousticness']
    track_info['valence'] = track_features[0]['valence']

    # Extract track URL
    track_info['track_url'] = track['external_urls']['spotify']

    # Check if all fields are filled and preview_url is not "[No preview url found]"
    if all(track_info.values()) and track_info['preview_url'] != "No preview url found":
        # Calculate angle
        track_info['angle_deg'] = EmotionCalculator.calculate_angle(arousal=track_info['arousal'], valence=track_info['valence'])

        # Determine quadrant
        track_info['quadrant'] = EmotionCalculator.determine_quadrant(angle_deg=track_info['angle_deg'])

        # Determine emotion
        track_info['emotion'] = EmotionCalculator.determine_emotion(quadrant_name=track_info['quadrant'])

        # Append track information to the list
        track_info_list.append(track_info)

# %%
track_info_list
# Out:
# [{'id': '0mvkwaZMP2gAy2ApQLtZRv',
#   'name': "It's a Beautiful Day",
#   'artists': ['Michael Bublé'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273051ae642ad4a0c1329b41d99',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02051ae642ad4a0c1329b41d99',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851051ae642ad4a0c1329b41d99',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/4c922c3bfb3b95b4e49fb6f76b055edae8432240?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.795,
#   'danceability': 0.532,
#   'acousticness': 0.0559,
#   'valence': 0.78,
#   'track_url': 'https://open.spotify.com/track/0mvkwaZMP2gAy2ApQLtZRv',
#   'angle_deg': 46.49433359126654,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '5fnA9mkIfScSqHIpeDyvck',
#   'name': 'Prayer in C - Robin Schulz Radio Edit',
#   'artists': ['Lilly Wood and The Prick', 'Robin Schulz'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2730538d5d965798a403219a470',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e020538d5d965798a403219a470',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048510538d5d965798a403219a470',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/8b4ea0fb47a5c8f4db5125f1ff69daf10045cfbb?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.875,
#   'danceability': 0.763,
#   'acousticness': 0.024,
#   'valence': 0.8,
#   'track_url': 'https://open.spotify.com/track/5fnA9mkIfScSqHIpeDyvck',
#   'angle_deg': 51.34019174590991,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '24y98VFyG8tA5Grb9hYSHn',
#   'name': 'Inna Jamaica',
#   'artists': ['Mellow Mood', 'Richie Campbell'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27346a96602db150aa1b3153019',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0246a96602db150aa1b3153019',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485146a96602db150aa1b3153019',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/1ad48d9aeecdb3fab472e1291fd40cfca4ec3f7f?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.795,
#   'danceability': 0.817,
#   'acousticness': 0.317,
#   'valence': 0.787,
#   'track_url': 'https://open.spotify.com/track/24y98VFyG8tA5Grb9hYSHn',
#   'angle_deg': 45.787521255670896,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '5MuNxNox3zTanAFIO5KcTl',
#   'name': "He's the Greatest Dancer - 1995 Remaster",
#   'artists': ['Sister Sledge'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273df7dd444dd50b02c2eecff40',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02df7dd444dd50b02c2eecff40',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851df7dd444dd50b02c2eecff40',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/1948926ace135bb5d7c0ed22b456e03d98232b23?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.815,
#   'danceability': 0.7,
#   'acousticness': 0.00115,
#   'valence': 0.837,
#   'track_url': 'https://open.spotify.com/track/5MuNxNox3zTanAFIO5KcTl',
#   'angle_deg': 43.06744003914111,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '1D9KEXIrlmPUkMTdYzqgX4',
#   'name': 'Thriller',
#   'artists': ['Michael Jackson'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27379b8d5f5821bddae3bc5e6a9',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0279b8d5f5821bddae3bc5e6a9',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485179b8d5f5821bddae3bc5e6a9',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/88ee624d48288c5e39bf2eef03e5921ba44adbbc?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.857,
#   'danceability': 0.776,
#   'acousticness': 0.0913,
#   'valence': 0.799,
#   'track_url': 'https://open.spotify.com/track/1D9KEXIrlmPUkMTdYzqgX4',
#   'angle_deg': 50.0526469547316,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '3pf96IFggfQuT6Gafqx2rt',
#   'name': 'Sunny',
#   'artists': ['Boney M.'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273dafd1cd6e9537ec8463ea691',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02dafd1cd6e9537ec8463ea691',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851dafd1cd6e9537ec8463ea691',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/dd07d16b7a206e52cb678355c9a061e20bc62c5e?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.868,
#   'danceability': 0.647,
#   'acousticness': 0.088,
#   'valence': 0.804,
#   'track_url': 'https://open.spotify.com/track/3pf96IFggfQuT6Gafqx2rt',
#   'angle_deg': 50.440332031005504,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '4fIWvT19w9PR0VVBuPYpWA',
#   'name': "Haven't Met You Yet",
#   'artists': ['Michael Bublé'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f0cc194252888c6658c706ab',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f0cc194252888c6658c706ab',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f0cc194252888c6658c706ab',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/a9b0dffb82b146a24cf005a3ada306bdbb1f81c5?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.733,
#   'danceability': 0.615,
#   'acousticness': 0.152,
#   'valence': 0.796,
#   'track_url': 'https://open.spotify.com/track/4fIWvT19w9PR0VVBuPYpWA',
#   'angle_deg': 38.20848267583966,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '46oKpr00CmuPJGvPZ3y9uk',
#   'name': "It's A Pity",
#   'artists': ['Tanya Stephens'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2731e38be43963dd54aebe5e829',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e021e38be43963dd54aebe5e829',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048511e38be43963dd54aebe5e829',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/bbb5a6736a06df664b5c532aa53069bf8187af1d?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.811,
#   'danceability': 0.66,
#   'acousticness': 0.00788,
#   'valence': 0.821,
#   'track_url': 'https://open.spotify.com/track/46oKpr00CmuPJGvPZ3y9uk',
#   'angle_deg': 44.09349685605196,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '0aAcuVJCmIkgVKzKHGfp1K',
#   'name': 'Hustler',
#   'artists': ['Ky-Mani Marley'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b58d1f8c9b136617f6ade775',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b58d1f8c9b136617f6ade775',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b58d1f8c9b136617f6ade775',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/6b7d2e9ad8e76776f757acc449e6879d4c8ed44d?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.762,
#   'danceability': 0.788,
#   'acousticness': 0.0515,
#   'valence': 0.792,
#   'track_url': 'https://open.spotify.com/track/0aAcuVJCmIkgVKzKHGfp1K',
#   'angle_deg': 41.90036787946869,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '59mA71ttclTLrO5Nsa7QUd',
#   'name': "We No Worry 'bout Them",
#   'artists': ['Konshens', 'Romain Virgo'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735a399fb4b07e70e952ef1d8a',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025a399fb4b07e70e952ef1d8a',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515a399fb4b07e70e952ef1d8a',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/dfd74465b99d1293224e630b17ce3f4113ec5b90?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.824,
#   'danceability': 0.691,
#   'acousticness': 0.029,
#   'valence': 0.756,
#   'track_url': 'https://open.spotify.com/track/59mA71ttclTLrO5Nsa7QUd',
#   'angle_deg': 51.68690932618235,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '605ZHoLZx7PtQ8fXgvN10K',
#   'name': 'Legalize It',
#   'artists': ['Peter Tosh'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273bf1823a0d9b8a5b5ad380833',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02bf1823a0d9b8a5b5ad380833',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851bf1823a0d9b8a5b5ad380833',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/f33beaa3aef943d4f5fdbc0652788a1d38be5ead?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.784,
#   'danceability': 0.701,
#   'acousticness': 0.128,
#   'valence': 0.712,
#   'track_url': 'https://open.spotify.com/track/605ZHoLZx7PtQ8fXgvN10K',
#   'angle_deg': 53.25943797987881,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '1YbbabJAtbmqCjMHGSqsrU',
#   'name': 'Holiday',
#   'artists': ['Hannah Arterton'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2730dbbf9fc3b2062979067f59d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e020dbbf9fc3b2062979067f59d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048510dbbf9fc3b2062979067f59d',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/ccc1f9d7c08f37f5f17e7fa7b7535b1380420cc3?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.754,
#   'danceability': 0.798,
#   'acousticness': 0.132,
#   'valence': 0.731,
#   'track_url': 'https://open.spotify.com/track/1YbbabJAtbmqCjMHGSqsrU',
#   'angle_deg': 47.7150853319196,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '0LqPXq2pKXnydc96PvTK3v',
#   'name': 'Everybody Dance - 12" Mix',
#   'artists': ['CHIC'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273d52e1afd97221bf55e937454',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02d52e1afd97221bf55e937454',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851d52e1afd97221bf55e937454',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/0a0f837011c82c6eb1b2df1ff7943ce030430c82?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.816,
#   'danceability': 0.764,
#   'acousticness': 0.0378,
#   'valence': 0.85,
#   'track_url': 'https://open.spotify.com/track/0LqPXq2pKXnydc96PvTK3v',
#   'angle_deg': 42.0775273319751,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '4E6TkulZSnor5RzOkkW32U',
#   'name': 'Superman',
#   'artists': ['Tarrus Riley'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273fe8f6f584c942c0f56206353',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02fe8f6f584c942c0f56206353',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851fe8f6f584c942c0f56206353',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/d1df40cd27005ccb6a5e8be2a75ef7c1197b1758?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.708,
#   'danceability': 0.656,
#   'acousticness': 0.169,
#   'valence': 0.824,
#   'track_url': 'https://open.spotify.com/track/4E6TkulZSnor5RzOkkW32U',
#   'angle_deg': 32.69946112100191,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '3XIEWK1V9n25PS9Vb6axj5',
#   'name': 'Born to Be Alive - The Original',
#   'artists': ['Patrick Hernandez'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b2622bac004d3ef8fac1095b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b2622bac004d3ef8fac1095b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b2622bac004d3ef8fac1095b',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/5898691af1ed6722dfb6d16340d92a39e55e383d?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.868,
#   'danceability': 0.704,
#   'acousticness': 0.0834,
#   'valence': 0.808,
#   'track_url': 'https://open.spotify.com/track/3XIEWK1V9n25PS9Vb6axj5',
#   'angle_deg': 50.0721328725145,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '1f5cbQtDrykjarZVrShaDI',
#   'name': 'Drowning (feat. Kodak Black)',
#   'artists': ['A Boogie Wit da Hoodie', 'Kodak Black'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273cdba7ee22968991250725ce1',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02cdba7ee22968991250725ce1',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851cdba7ee22968991250725ce1',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/f770a1a0b3dfb5bc652f89848e45ab9d09f7dc69?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.81,
#   'danceability': 0.839,
#   'acousticness': 0.501,
#   'valence': 0.814,
#   'track_url': 'https://open.spotify.com/track/1f5cbQtDrykjarZVrShaDI',
#   'angle_deg': 44.63272439266191,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '7nD9nN3jord9wWcfW3Gkcm',
#   'name': 'All In My Head (Flex) (feat. Fetty Wap)',
#   'artists': ['Fifth Harmony', 'Fetty Wap'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273d03fa6f4e758282b7920b5c8',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02d03fa6f4e758282b7920b5c8',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851d03fa6f4e758282b7920b5c8',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/919cbfbef09365ed8ce9481ec8b2699a970c12e7?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.791,
#   'danceability': 0.689,
#   'acousticness': 0.023,
#   'valence': 0.755,
#   'track_url': 'https://open.spotify.com/track/7nD9nN3jord9wWcfW3Gkcm',
#   'angle_deg': 48.77228360937985,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '7zpm7lTY2EZn7AfFm3mGg2',
#   'name': 'Lost in Music - 1995 Remaster',
#   'artists': ['Sister Sledge'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2733bf5ea3a790675d745115e93',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e023bf5ea3a790675d745115e93',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048513bf5ea3a790675d745115e93',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/57d447011ac59dc6729538bf0c2f433af2284fc2?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.841,
#   'danceability': 0.758,
#   'acousticness': 0.0544,
#   'valence': 0.849,
#   'track_url': 'https://open.spotify.com/track/7zpm7lTY2EZn7AfFm3mGg2',
#   'angle_deg': 44.33573087094011,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '1nsEptcDye2MUjMJQ1N5Rh',
#   'name': 'Revolution',
#   'artists': ['Dennis Brown'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b6960dcd965137037003c10e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b6960dcd965137037003c10e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b6960dcd965137037003c10e',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/e0f895920b374e8368c2e4781ddb9ba4b87a70b1?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.719,
#   'danceability': 0.717,
#   'acousticness': 0.199,
#   'valence': 0.766,
#   'track_url': 'https://open.spotify.com/track/1nsEptcDye2MUjMJQ1N5Rh',
#   'angle_deg': 39.46490900765044,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '6rrTr2HEAzlpC4KWZxF3S1',
#   'name': 'Woman Like Me (feat. Nicki Minaj)',
#   'artists': ['Little Mix', 'Nicki Minaj'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273740e5073699ef09f02d73d05',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02740e5073699ef09f02d73d05',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851740e5073699ef09f02d73d05',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/14aaf400d0bc7d21a6a56f620da0c82b01d17d0d?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.849,
#   'danceability': 0.757,
#   'acousticness': 0.173,
#   'valence': 0.826,
#   'track_url': 'https://open.spotify.com/track/6rrTr2HEAzlpC4KWZxF3S1',
#   'angle_deg': 46.95154559315338,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '2Foc5Q5nqNiosCNqttzHof',
#   'name': 'Get Lucky (Radio Edit) [feat. Pharrell Williams and Nile Rodgers]',
#   'artists': ['Daft Punk', 'Pharrell Williams', 'Nile Rodgers'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2731d5cf960a92bb8b03fc2be7f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e021d5cf960a92bb8b03fc2be7f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048511d5cf960a92bb8b03fc2be7f',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/9b7eaf7fb5cab29251df52e9a4f46fad14e29aa1?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.811,
#   'danceability': 0.794,
#   'acousticness': 0.0426,
#   'valence': 0.862,
#   'track_url': 'https://open.spotify.com/track/2Foc5Q5nqNiosCNqttzHof',
#   'angle_deg': 40.66640345733477,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '2NVpYQqdraEcQwqT7GhUkh',
#   'name': "Ain't Nobody",
#   'artists': ['Chaka Khan'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2734c5fac07f80bad278dfbad1e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e024c5fac07f80bad278dfbad1e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048514c5fac07f80bad278dfbad1e',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/b6edffa027765a5c5a9581da93b5c51be54dcaf6?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.878,
#   'danceability': 0.8,
#   'acousticness': 0.189,
#   'valence': 0.816,
#   'track_url': 'https://open.spotify.com/track/2NVpYQqdraEcQwqT7GhUkh',
#   'angle_deg': 50.10509044659229,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '3sbBOn0ifcgoX3MfaTeFKr',
#   'name': 'Still Blazing',
#   'artists': ['Alborosie'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/2f6db9fd9319c6d8e30ed034fd7a8f19fc41c65f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ef9b95184c7d04a48d71f75a74ec29874ac42eb2',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ca9d906ea2f59d51a1b174a0b29993b2aad966ce',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/0c4eb3e34ee003d098118c1bc32439857860e421?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.704,
#   'danceability': 0.749,
#   'acousticness': 0.0159,
#   'valence': 0.821,
#   'track_url': 'https://open.spotify.com/track/3sbBOn0ifcgoX3MfaTeFKr',
#   'angle_deg': 32.43653060148162,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '49SgioQeGOwNYJJYT4fqmz',
#   'name': 'The Other Boys (feat. Kylie Minogue, Jake Shears & Nile Rodgers)',
#   'artists': ['NERVO', 'Kylie Minogue', 'Jake Shears', 'Nile Rodgers'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c46534ae5b5ec2ca34dc627c',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c46534ae5b5ec2ca34dc627c',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c46534ae5b5ec2ca34dc627c',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/d6bdf22155adf5e0e508dcde0e7e18c86126ae6d?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.844,
#   'danceability': 0.654,
#   'acousticness': 0.001,
#   'valence': 0.843,
#   'track_url': 'https://open.spotify.com/track/49SgioQeGOwNYJJYT4fqmz',
#   'angle_deg': 45.083399911277084,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '0s45sL9DLOcro6VbmagQKl',
#   'name': 'Rock the Boat',
#   'artists': ['Hues Corporation'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273871ab8561721e8967eda8269',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02871ab8561721e8967eda8269',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851871ab8561721e8967eda8269',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/c5338e76a51bbbbcce0d388f1449f56c070e1f61?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.71,
#   'danceability': 0.606,
#   'acousticness': 0.328,
#   'valence': 0.795,
#   'track_url': 'https://open.spotify.com/track/0s45sL9DLOcro6VbmagQKl',
#   'angle_deg': 35.44571032759823,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'}]

# %%
i = 0

for track_info in track_info_list:
      # Increment the track number
      i += 1

      # Printing track information
      print(f"\nTrack {i}:")
      print("Track ID:", track_info['id'])
      print("Track Name:", track_info['name'])

      # Printing artists
      print("Artists:", ', '.join(track_info['artists']))

      # print track url
      print("Track URL:", track_info['track_url'])

      # Printing preview URL
      print("Preview URL:", track_info['preview_url'])

      # Printing Track Features
      print("Arousal:", track_info['arousal'])
      print("Valence:", track_info['valence'])

      # Printing Track Quadrants
      print("Angle:", track_info['angle_deg'])
      print("Quadrant:", track_info['quadrant'])
      print("Emotion:", track_info['emotion'])
# Out:
# Track 1:
# Track ID: 0mvkwaZMP2gAy2ApQLtZRv
# Track Name: It's a Beautiful Day
# Artists: Michael Bublé
# Track URL: https://open.spotify.com/track/0mvkwaZMP2gAy2ApQLtZRv
# Preview URL: https://p.scdn.co/mp3-preview/4c922c3bfb3b95b4e49fb6f76b055edae8432240?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.795
# Valence: 0.78
# Angle: 46.49433359126654
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 2:
# Track ID: 5fnA9mkIfScSqHIpeDyvck
# Track Name: Prayer in C - Robin Schulz Radio Edit
# Artists: Lilly Wood and The Prick, Robin Schulz
# Track URL: https://open.spotify.com/track/5fnA9mkIfScSqHIpeDyvck
# Preview URL: https://p.scdn.co/mp3-preview/8b4ea0fb47a5c8f4db5125f1ff69daf10045cfbb?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.875
# Valence: 0.8
# Angle: 51.34019174590991
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 3:
# Track ID: 24y98VFyG8tA5Grb9hYSHn
# Track Name: Inna Jamaica
# Artists: Mellow Mood, Richie Campbell
# Track URL: https://open.spotify.com/track/24y98VFyG8tA5Grb9hYSHn
# Preview URL: https://p.scdn.co/mp3-preview/1ad48d9aeecdb3fab472e1291fd40cfca4ec3f7f?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.795
# Valence: 0.787
# Angle: 45.787521255670896
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 4:
# Track ID: 5MuNxNox3zTanAFIO5KcTl
# Track Name: He's the Greatest Dancer - 1995 Remaster
# Artists: Sister Sledge
# Track URL: https://open.spotify.com/track/5MuNxNox3zTanAFIO5KcTl
# Preview URL: https://p.scdn.co/mp3-preview/1948926ace135bb5d7c0ed22b456e03d98232b23?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.815
# Valence: 0.837
# Angle: 43.06744003914111
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 5:
# Track ID: 1D9KEXIrlmPUkMTdYzqgX4
# Track Name: Thriller
# Artists: Michael Jackson
# Track URL: https://open.spotify.com/track/1D9KEXIrlmPUkMTdYzqgX4
# Preview URL: https://p.scdn.co/mp3-preview/88ee624d48288c5e39bf2eef03e5921ba44adbbc?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.857
# Valence: 0.799
# Angle: 50.0526469547316
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 6:
# Track ID: 3pf96IFggfQuT6Gafqx2rt
# Track Name: Sunny
# Artists: Boney M.
# Track URL: https://open.spotify.com/track/3pf96IFggfQuT6Gafqx2rt
# Preview URL: https://p.scdn.co/mp3-preview/dd07d16b7a206e52cb678355c9a061e20bc62c5e?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.868
# Valence: 0.804
# Angle: 50.440332031005504
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 7:
# Track ID: 4fIWvT19w9PR0VVBuPYpWA
# Track Name: Haven't Met You Yet
# Artists: Michael Bublé
# Track URL: https://open.spotify.com/track/4fIWvT19w9PR0VVBuPYpWA
# Preview URL: https://p.scdn.co/mp3-preview/a9b0dffb82b146a24cf005a3ada306bdbb1f81c5?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.733
# Valence: 0.796
# Angle: 38.20848267583966
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 8:
# Track ID: 46oKpr00CmuPJGvPZ3y9uk
# Track Name: It's A Pity
# Artists: Tanya Stephens
# Track URL: https://open.spotify.com/track/46oKpr00CmuPJGvPZ3y9uk
# Preview URL: https://p.scdn.co/mp3-preview/bbb5a6736a06df664b5c532aa53069bf8187af1d?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.811
# Valence: 0.821
# Angle: 44.09349685605196
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 9:
# Track ID: 0aAcuVJCmIkgVKzKHGfp1K
# Track Name: Hustler
# Artists: Ky-Mani Marley
# Track URL: https://open.spotify.com/track/0aAcuVJCmIkgVKzKHGfp1K
# Preview URL: https://p.scdn.co/mp3-preview/6b7d2e9ad8e76776f757acc449e6879d4c8ed44d?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.762
# Valence: 0.792
# Angle: 41.90036787946869
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 10:
# Track ID: 59mA71ttclTLrO5Nsa7QUd
# Track Name: We No Worry 'bout Them
# Artists: Konshens, Romain Virgo
# Track URL: https://open.spotify.com/track/59mA71ttclTLrO5Nsa7QUd
# Preview URL: https://p.scdn.co/mp3-preview/dfd74465b99d1293224e630b17ce3f4113ec5b90?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.824
# Valence: 0.756
# Angle: 51.68690932618235
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 11:
# Track ID: 605ZHoLZx7PtQ8fXgvN10K
# Track Name: Legalize It
# Artists: Peter Tosh
# Track URL: https://open.spotify.com/track/605ZHoLZx7PtQ8fXgvN10K
# Preview URL: https://p.scdn.co/mp3-preview/f33beaa3aef943d4f5fdbc0652788a1d38be5ead?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.784
# Valence: 0.712
# Angle: 53.25943797987881
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 12:
# Track ID: 1YbbabJAtbmqCjMHGSqsrU
# Track Name: Holiday
# Artists: Hannah Arterton
# Track URL: https://open.spotify.com/track/1YbbabJAtbmqCjMHGSqsrU
# Preview URL: https://p.scdn.co/mp3-preview/ccc1f9d7c08f37f5f17e7fa7b7535b1380420cc3?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.754
# Valence: 0.731
# Angle: 47.7150853319196
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 13:
# Track ID: 0LqPXq2pKXnydc96PvTK3v
# Track Name: Everybody Dance - 12" Mix
# Artists: CHIC
# Track URL: https://open.spotify.com/track/0LqPXq2pKXnydc96PvTK3v
# Preview URL: https://p.scdn.co/mp3-preview/0a0f837011c82c6eb1b2df1ff7943ce030430c82?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.816
# Valence: 0.85
# Angle: 42.0775273319751
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 14:
# Track ID: 4E6TkulZSnor5RzOkkW32U
# Track Name: Superman
# Artists: Tarrus Riley
# Track URL: https://open.spotify.com/track/4E6TkulZSnor5RzOkkW32U
# Preview URL: https://p.scdn.co/mp3-preview/d1df40cd27005ccb6a5e8be2a75ef7c1197b1758?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.708
# Valence: 0.824
# Angle: 32.69946112100191
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 15:
# Track ID: 3XIEWK1V9n25PS9Vb6axj5
# Track Name: Born to Be Alive - The Original
# Artists: Patrick Hernandez
# Track URL: https://open.spotify.com/track/3XIEWK1V9n25PS9Vb6axj5
# Preview URL: https://p.scdn.co/mp3-preview/5898691af1ed6722dfb6d16340d92a39e55e383d?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.868
# Valence: 0.808
# Angle: 50.0721328725145
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 16:
# Track ID: 1f5cbQtDrykjarZVrShaDI
# Track Name: Drowning (feat. Kodak Black)
# Artists: A Boogie Wit da Hoodie, Kodak Black
# Track URL: https://open.spotify.com/track/1f5cbQtDrykjarZVrShaDI
# Preview URL: https://p.scdn.co/mp3-preview/f770a1a0b3dfb5bc652f89848e45ab9d09f7dc69?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.81
# Valence: 0.814
# Angle: 44.63272439266191
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 17:
# Track ID: 7nD9nN3jord9wWcfW3Gkcm
# Track Name: All In My Head (Flex) (feat. Fetty Wap)
# Artists: Fifth Harmony, Fetty Wap
# Track URL: https://open.spotify.com/track/7nD9nN3jord9wWcfW3Gkcm
# Preview URL: https://p.scdn.co/mp3-preview/919cbfbef09365ed8ce9481ec8b2699a970c12e7?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.791
# Valence: 0.755
# Angle: 48.77228360937985
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 18:
# Track ID: 7zpm7lTY2EZn7AfFm3mGg2
# Track Name: Lost in Music - 1995 Remaster
# Artists: Sister Sledge
# Track URL: https://open.spotify.com/track/7zpm7lTY2EZn7AfFm3mGg2
# Preview URL: https://p.scdn.co/mp3-preview/57d447011ac59dc6729538bf0c2f433af2284fc2?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.841
# Valence: 0.849
# Angle: 44.33573087094011
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 19:
# Track ID: 1nsEptcDye2MUjMJQ1N5Rh
# Track Name: Revolution
# Artists: Dennis Brown
# Track URL: https://open.spotify.com/track/1nsEptcDye2MUjMJQ1N5Rh
# Preview URL: https://p.scdn.co/mp3-preview/e0f895920b374e8368c2e4781ddb9ba4b87a70b1?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.719
# Valence: 0.766
# Angle: 39.46490900765044
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 20:
# Track ID: 6rrTr2HEAzlpC4KWZxF3S1
# Track Name: Woman Like Me (feat. Nicki Minaj)
# Artists: Little Mix, Nicki Minaj
# Track URL: https://open.spotify.com/track/6rrTr2HEAzlpC4KWZxF3S1
# Preview URL: https://p.scdn.co/mp3-preview/14aaf400d0bc7d21a6a56f620da0c82b01d17d0d?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.849
# Valence: 0.826
# Angle: 46.95154559315338
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 21:
# Track ID: 2Foc5Q5nqNiosCNqttzHof
# Track Name: Get Lucky (Radio Edit) [feat. Pharrell Williams and Nile Rodgers]
# Artists: Daft Punk, Pharrell Williams, Nile Rodgers
# Track URL: https://open.spotify.com/track/2Foc5Q5nqNiosCNqttzHof
# Preview URL: https://p.scdn.co/mp3-preview/9b7eaf7fb5cab29251df52e9a4f46fad14e29aa1?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.811
# Valence: 0.862
# Angle: 40.66640345733477
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 22:
# Track ID: 2NVpYQqdraEcQwqT7GhUkh
# Track Name: Ain't Nobody
# Artists: Chaka Khan
# Track URL: https://open.spotify.com/track/2NVpYQqdraEcQwqT7GhUkh
# Preview URL: https://p.scdn.co/mp3-preview/b6edffa027765a5c5a9581da93b5c51be54dcaf6?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.878
# Valence: 0.816
# Angle: 50.10509044659229
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 23:
# Track ID: 3sbBOn0ifcgoX3MfaTeFKr
# Track Name: Still Blazing
# Artists: Alborosie
# Track URL: https://open.spotify.com/track/3sbBOn0ifcgoX3MfaTeFKr
# Preview URL: https://p.scdn.co/mp3-preview/0c4eb3e34ee003d098118c1bc32439857860e421?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.704
# Valence: 0.821
# Angle: 32.43653060148162
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 24:
# Track ID: 49SgioQeGOwNYJJYT4fqmz
# Track Name: The Other Boys (feat. Kylie Minogue, Jake Shears & Nile Rodgers)
# Artists: NERVO, Kylie Minogue, Jake Shears, Nile Rodgers
# Track URL: https://open.spotify.com/track/49SgioQeGOwNYJJYT4fqmz
# Preview URL: https://p.scdn.co/mp3-preview/d6bdf22155adf5e0e508dcde0e7e18c86126ae6d?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.844
# Valence: 0.843
# Angle: 45.083399911277084
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 25:
# Track ID: 0s45sL9DLOcro6VbmagQKl
# Track Name: Rock the Boat
# Artists: Hues Corporation
# Track URL: https://open.spotify.com/track/0s45sL9DLOcro6VbmagQKl
# Preview URL: https://p.scdn.co/mp3-preview/c5338e76a51bbbbcce0d388f1449f56c070e1f61?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.71
# Valence: 0.795
# Angle: 35.44571032759823
# Quadrant: QUAD1
# Emotion: Happiness

# %%
your_predicted_emotion = "Happiness"

# %%
# Filter tracks by predicted emotion
filtered_tracks = [track for track in track_info_list if track['emotion'] == your_predicted_emotion]

# If the length of filtered_tracks is less than 5, include tracks with other emotions
if len(filtered_tracks) < 5:
  other_tracks = [track for track in track_info_list if track['emotion'] != your_predicted_emotion]
  filtered_tracks += other_tracks[:5 - len(filtered_tracks)]

# Sort tracks by their angle_deg
filtered_tracks.sort(key=lambda track: track['angle_deg'])

# Calculate the mean of angles in filtered tracks using NumPy
mean_angle = np.mean([track['angle_deg'] for track in filtered_tracks])

# Sort tracks by their angle difference from the mean angle using NumPy
sorted_indices = np.argsort(np.abs([track['angle_deg'] - mean_angle for track in filtered_tracks]))

# Get the top 10 tracks with angles closest to the mean angle
top_10_tracks = [filtered_tracks[i] for i in sorted_indices[:10]]

top_10_tracks
# Out:
# [{'id': '1f5cbQtDrykjarZVrShaDI',
#   'name': 'Drowning (feat. Kodak Black)',
#   'artists': ['A Boogie Wit da Hoodie', 'Kodak Black'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273cdba7ee22968991250725ce1',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02cdba7ee22968991250725ce1',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851cdba7ee22968991250725ce1',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/f770a1a0b3dfb5bc652f89848e45ab9d09f7dc69?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.81,
#   'danceability': 0.839,
#   'acousticness': 0.501,
#   'valence': 0.814,
#   'track_url': 'https://open.spotify.com/track/1f5cbQtDrykjarZVrShaDI',
#   'angle_deg': 44.63272439266191,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '7zpm7lTY2EZn7AfFm3mGg2',
#   'name': 'Lost in Music - 1995 Remaster',
#   'artists': ['Sister Sledge'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2733bf5ea3a790675d745115e93',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e023bf5ea3a790675d745115e93',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048513bf5ea3a790675d745115e93',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/57d447011ac59dc6729538bf0c2f433af2284fc2?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.841,
#   'danceability': 0.758,
#   'acousticness': 0.0544,
#   'valence': 0.849,
#   'track_url': 'https://open.spotify.com/track/7zpm7lTY2EZn7AfFm3mGg2',
#   'angle_deg': 44.33573087094011,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '49SgioQeGOwNYJJYT4fqmz',
#   'name': 'The Other Boys (feat. Kylie Minogue, Jake Shears & Nile Rodgers)',
#   'artists': ['NERVO', 'Kylie Minogue', 'Jake Shears', 'Nile Rodgers'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c46534ae5b5ec2ca34dc627c',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c46534ae5b5ec2ca34dc627c',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c46534ae5b5ec2ca34dc627c',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/d6bdf22155adf5e0e508dcde0e7e18c86126ae6d?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.844,
#   'danceability': 0.654,
#   'acousticness': 0.001,
#   'valence': 0.843,
#   'track_url': 'https://open.spotify.com/track/49SgioQeGOwNYJJYT4fqmz',
#   'angle_deg': 45.083399911277084,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '46oKpr00CmuPJGvPZ3y9uk',
#   'name': "It's A Pity",
#   'artists': ['Tanya Stephens'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2731e38be43963dd54aebe5e829',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e021e38be43963dd54aebe5e829',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048511e38be43963dd54aebe5e829',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/bbb5a6736a06df664b5c532aa53069bf8187af1d?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.811,
#   'danceability': 0.66,
#   'acousticness': 0.00788,
#   'valence': 0.821,
#   'track_url': 'https://open.spotify.com/track/46oKpr00CmuPJGvPZ3y9uk',
#   'angle_deg': 44.09349685605196,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '24y98VFyG8tA5Grb9hYSHn',
#   'name': 'Inna Jamaica',
#   'artists': ['Mellow Mood', 'Richie Campbell'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27346a96602db150aa1b3153019',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0246a96602db150aa1b3153019',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485146a96602db150aa1b3153019',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/1ad48d9aeecdb3fab472e1291fd40cfca4ec3f7f?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.795,
#   'danceability': 0.817,
#   'acousticness': 0.317,
#   'valence': 0.787,
#   'track_url': 'https://open.spotify.com/track/24y98VFyG8tA5Grb9hYSHn',
#   'angle_deg': 45.787521255670896,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '5MuNxNox3zTanAFIO5KcTl',
#   'name': "He's the Greatest Dancer - 1995 Remaster",
#   'artists': ['Sister Sledge'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273df7dd444dd50b02c2eecff40',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02df7dd444dd50b02c2eecff40',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851df7dd444dd50b02c2eecff40',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/1948926ace135bb5d7c0ed22b456e03d98232b23?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.815,
#   'danceability': 0.7,
#   'acousticness': 0.00115,
#   'valence': 0.837,
#   'track_url': 'https://open.spotify.com/track/5MuNxNox3zTanAFIO5KcTl',
#   'angle_deg': 43.06744003914111,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '0mvkwaZMP2gAy2ApQLtZRv',
#   'name': "It's a Beautiful Day",
#   'artists': ['Michael Bublé'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273051ae642ad4a0c1329b41d99',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02051ae642ad4a0c1329b41d99',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851051ae642ad4a0c1329b41d99',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/4c922c3bfb3b95b4e49fb6f76b055edae8432240?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.795,
#   'danceability': 0.532,
#   'acousticness': 0.0559,
#   'valence': 0.78,
#   'track_url': 'https://open.spotify.com/track/0mvkwaZMP2gAy2ApQLtZRv',
#   'angle_deg': 46.49433359126654,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '6rrTr2HEAzlpC4KWZxF3S1',
#   'name': 'Woman Like Me (feat. Nicki Minaj)',
#   'artists': ['Little Mix', 'Nicki Minaj'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273740e5073699ef09f02d73d05',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02740e5073699ef09f02d73d05',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851740e5073699ef09f02d73d05',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/14aaf400d0bc7d21a6a56f620da0c82b01d17d0d?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.849,
#   'danceability': 0.757,
#   'acousticness': 0.173,
#   'valence': 0.826,
#   'track_url': 'https://open.spotify.com/track/6rrTr2HEAzlpC4KWZxF3S1',
#   'angle_deg': 46.95154559315338,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '0LqPXq2pKXnydc96PvTK3v',
#   'name': 'Everybody Dance - 12" Mix',
#   'artists': ['CHIC'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273d52e1afd97221bf55e937454',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02d52e1afd97221bf55e937454',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851d52e1afd97221bf55e937454',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/0a0f837011c82c6eb1b2df1ff7943ce030430c82?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.816,
#   'danceability': 0.764,
#   'acousticness': 0.0378,
#   'valence': 0.85,
#   'track_url': 'https://open.spotify.com/track/0LqPXq2pKXnydc96PvTK3v',
#   'angle_deg': 42.0775273319751,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '0aAcuVJCmIkgVKzKHGfp1K',
#   'name': 'Hustler',
#   'artists': ['Ky-Mani Marley'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b58d1f8c9b136617f6ade775',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b58d1f8c9b136617f6ade775',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b58d1f8c9b136617f6ade775',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/6b7d2e9ad8e76776f757acc449e6879d4c8ed44d?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.762,
#   'danceability': 0.788,
#   'acousticness': 0.0515,
#   'valence': 0.792,
#   'track_url': 'https://open.spotify.com/track/0aAcuVJCmIkgVKzKHGfp1K',
#   'angle_deg': 41.90036787946869,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'}]

# %% [markdown]
# # DF Visualization

# %%
import pandas as pd

df = pd.DataFrame(top_10_tracks)

# %%
df.drop(columns=['images'], inplace=True)

# %%
df
# Out:
#                        id                                               name  \
# 0  1f5cbQtDrykjarZVrShaDI                       Drowning (feat. Kodak Black)
# 1  7zpm7lTY2EZn7AfFm3mGg2                      Lost in Music - 1995 Remaster
# 2  49SgioQeGOwNYJJYT4fqmz  The Other Boys (feat. Kylie Minogue, Jake Shea...
# 3  46oKpr00CmuPJGvPZ3y9uk                                        It's A Pity
# 4  24y98VFyG8tA5Grb9hYSHn                                       Inna Jamaica
# 5  5MuNxNox3zTanAFIO5KcTl           He's the Greatest Dancer - 1995 Remaster
# 6  0mvkwaZMP2gAy2ApQLtZRv                               It's a Beautiful Day
# 7  6rrTr2HEAzlpC4KWZxF3S1                  Woman Like Me (feat. Nicki Minaj)
# 8  0LqPXq2pKXnydc96PvTK3v                          Everybody Dance - 12" Mix
# 9  0aAcuVJCmIkgVKzKHGfp1K                                            Hustler
#
#                                              artists  \
# 0              [A Boogie Wit da Hoodie, Kodak Black]
# 1                                    [Sister Sledge]
# 2  [NERVO, Kylie Minogue, Jake Shears, Nile Rodgers]
# 3                                   [Tanya Stephens]
# 4                     [Mellow Mood, Richie Campbell]
# 5                                    [Sister Sledge]
# 6                                    [Michael Bublé]
# 7                          [Little Mix, Nicki Minaj]
# 8                                             [CHIC]
# 9                                   [Ky-Mani Marley]
#
#                                          preview_url  arousal  danceability  \
# 0  https://p.scdn.co/mp3-preview/f770a1a0b3dfb5bc...    0.810         0.839
# 1  https://p.scdn.co/mp3-preview/57d447011ac59dc6...    0.841         0.758
# 2  https://p.scdn.co/mp3-preview/d6bdf22155adf5e0...    0.844         0.654
# 3  https://p.scdn.co/mp3-preview/bbb5a6736a06df66...    0.811         0.660
# 4  https://p.scdn.co/mp3-preview/1ad48d9aeecdb3fa...    0.795         0.817
# 5  https://p.scdn.co/mp3-preview/1948926ace135bb5...    0.815         0.700
# 6  https://p.scdn.co/mp3-preview/4c922c3bfb3b95b4...    0.795         0.532
# 7  https://p.scdn.co/mp3-preview/14aaf400d0bc7d21...    0.849         0.757
# 8  https://p.scdn.co/mp3-preview/0a0f837011c82c6e...    0.816         0.764
# 9  https://p.scdn.co/mp3-preview/6b7d2e9ad8e76776...    0.762         0.788
#
#    acousticness  valence                                          track_url  \
# 0       0.50100    0.814  https://open.spotify.com/track/1f5cbQtDrykjarZ...
# 1       0.05440    0.849  https://open.spotify.com/track/7zpm7lTY2EZn7Af...
# 2       0.00100    0.843  https://open.spotify.com/track/49SgioQeGOwNYJJ...
# 3       0.00788    0.821  https://open.spotify.com/track/46oKpr00CmuPJGv...
# 4       0.31700    0.787  https://open.spotify.com/track/24y98VFyG8tA5Gr...
# 5       0.00115    0.837  https://open.spotify.com/track/5MuNxNox3zTanAF...
# 6       0.05590    0.780  https://open.spotify.com/track/0mvkwaZMP2gAy2A...
# 7       0.17300    0.826  https://open.spotify.com/track/6rrTr2HEAzlpC4K...
# 8       0.03780    0.850  https://open.spotify.com/track/0LqPXq2pKXnydc9...
# 9       0.05150    0.792  https://open.spotify.com/track/0aAcuVJCmIkgVKz...
#
#    angle_deg quadrant    emotion
# 0  44.632724    QUAD1  Happiness
# 1  44.335731    QUAD1  Happiness
# 2  45.083400    QUAD1  Happiness
# 3  44.093497    QUAD1  Happiness
# 4  45.787521    QUAD1  Happiness
# 5  43.067440    QUAD1  Happiness
# 6  46.494334    QUAD1  Happiness
# 7  46.951546    QUAD1  Happiness
# 8  42.077527    QUAD1  Happiness
# 9  41.900368    QUAD1  Happiness
