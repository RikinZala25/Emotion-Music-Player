# %% [markdown]
# # Spotify - Search by Speech Keywords

# %% [markdown]
# Q1 as high valence high arousal (HVHA) - Happy,
#
# Q2 as low valence high arousal (LVHA) - Angry,
#
# Q3 as low valence low arousal (LVLA) - Sad,
#
# Q4 as high valence low arousal (HVLA) - Calm.

# %%
# !pip install spotipy

# %%
from google.colab import userdata

# %%
import json, requests
import numpy as np

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(
    auth_manager=SpotifyClientCredentials(
        client_id='EBMP_APP_CLIENT_ID',
        client_secret='EBMP_CLIENT_SECRET'
        )
    )

# %%
output = sp.search("Cold Nights", limit=30, offset=0, type='track', market='US')

# %%
class EmotionCalculator:
    @staticmethod
    def calculate_angle(arousal, valence):
        # Scale arousal and valence to [-1, 1] range
        arousal_scaled = 2 * arousal - 1
        valence_scaled = 2 * valence - 1
        # Calculate the angle in radians
        angle_rad = np.arctan2(arousal_scaled, valence_scaled)
        # Convert radians to degrees
        angle_deg = np.degrees(angle_rad)
        # Ensure angle is positive
        if angle_deg < 0:
            angle_deg += 360
        return angle_deg

    @staticmethod
    def determine_quadrant(angle_deg):
        if 0 <= angle_deg < 90:
            return "QUAD1"
        elif 90 <= angle_deg < 180:
            return "QUAD2"
        elif 180 <= angle_deg < 270:
            return "QUAD3"
        else:
            return "QUAD4"

    @staticmethod
    def determine_emotion(quadrant_name):
        if quadrant_name == "QUAD1":
            return "Happiness"
        elif quadrant_name == "QUAD2":
            return "Anger"
        elif quadrant_name == "QUAD3":
            return "Sadness"
        else:
            return "Calmness"

# %%
available_markets = ["US", "GB", "DE", "FR", "BR", "JP", "RU", "IN", "KR", "ES"]

def get_preview_url(track_id):
    for market in available_markets:
        try:
            output = sp.track(track_id, market=market)
            if output['preview_url']:
                return output['preview_url']
        except Exception as e:
            print(f"Error occurred: {e}")
    return "No preview url found"

# %%
# Number of limits specified
limit = 20

# List to store track information
track_info_list = []

for i in range(min(limit, len(output["tracks"]["items"]))):
    track_info = {}
    track = output["tracks"]["items"][i]

    # Extracting track ID and name
    track_info['id'] = track['id']
    track_info['name'] = track['name']

    # Extracting artists' names
    track_info['artists'] = [artist['name'] for artist in track['artists']]

    # Extracting images details
    track_info['images'] = track['album']['images']

    # Extracting preview URL if available
    if 'preview_url' in track and track['preview_url'] is not None:
      track_info['preview_url'] = track['preview_url']
    else:
      track_info['preview_url'] = get_preview_url(track['id'])

    # Extract the track features
    track_features = sp.audio_features(track['id'])
    track_info['arousal'] = track_features[0]['energy']
    track_info['danceability'] = track_features[0]['danceability']
    track_info['acousticness'] = track_features[0]['acousticness']
    track_info['valence'] = track_features[0]['valence']

    # Extract track URL
    track_info['track_url'] = track['external_urls']['spotify']

    # Check if all fields are filled and preview_url is not "[No preview url found]"
    if all(track_info.values()) and track_info['preview_url'] != "No preview url found":
        # Calculate angle
        track_info['angle_deg'] = EmotionCalculator.calculate_angle(arousal=track_info['arousal'], valence=track_info['valence'])

        # Determine quadrant
        track_info['quadrant'] = EmotionCalculator.determine_quadrant(angle_deg=track_info['angle_deg'])

        # Determine emotion
        track_info['emotion'] = EmotionCalculator.determine_emotion(quadrant_name=track_info['quadrant'])

        # Append track information to the list
        track_info_list.append(track_info)

# %%
track_info_list
# Out:
# [{'id': '1bwlBQYp4KgABzsi9s7nzx',
#   'name': 'Cold Nights',
#   'artists': ['Hulvey'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2733aaaeab5117e8b8f776596cb',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e023aaaeab5117e8b8f776596cb',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048513aaaeab5117e8b8f776596cb',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/f29afc5cb3caecd897937b4f9a71dd7fe4b6e603?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.571,
#   'danceability': 0.762,
#   'acousticness': 0.0342,
#   'valence': 0.395,
#   'track_url': 'https://open.spotify.com/track/1bwlBQYp4KgABzsi9s7nzx',
#   'angle_deg': 145.93381678575582,
#   'quadrant': 'QUAD2',
#   'emotion': 'Anger'},
#  {'id': '4gKYW7JKLAO5KPwadZASPm',
#   'name': 'Cold Nights in Hollywood',
#   'artists': ['Buppy.'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273dc719d68f6343909eaeaedcd',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02dc719d68f6343909eaeaedcd',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851dc719d68f6343909eaeaedcd',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/05033b2d9f5ecfcfc90b658d35ea878efa6680bd?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.494,
#   'danceability': 0.659,
#   'acousticness': 0.576,
#   'valence': 0.239,
#   'track_url': 'https://open.spotify.com/track/4gKYW7JKLAO5KPwadZASPm',
#   'angle_deg': 181.31691240579326,
#   'quadrant': 'QUAD3',
#   'emotion': 'Sadness'},
#  {'id': '7v0mCN6KkwIuDSZJm3Tzl8',
#   'name': 'Cold Nights',
#   'artists': ['$tupid Young'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273fcc462398eda5bae81d29066',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02fcc462398eda5bae81d29066',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851fcc462398eda5bae81d29066',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/1d6b48d0f954a2641960045d3556da27d9503554?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.535,
#   'danceability': 0.774,
#   'acousticness': 0.384,
#   'valence': 0.27,
#   'track_url': 'https://open.spotify.com/track/7v0mCN6KkwIuDSZJm3Tzl8',
#   'angle_deg': 171.34745820888529,
#   'quadrant': 'QUAD2',
#   'emotion': 'Anger'},
#  {'id': '3OxH1yJ35RIN47bUEx3JaX',
#   'name': 'Cold Nights',
#   'artists': ['Pauli Gabrieli'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e5f13965ebbca3362c48b3a5',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e5f13965ebbca3362c48b3a5',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e5f13965ebbca3362c48b3a5',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/c887a88a86effcfea31f2d9dd798fedfd1aa00aa?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.667,
#   'danceability': 0.837,
#   'acousticness': 0.0211,
#   'valence': 0.115,
#   'track_url': 'https://open.spotify.com/track/3OxH1yJ35RIN47bUEx3JaX',
#   'angle_deg': 156.55042832784196,
#   'quadrant': 'QUAD2',
#   'emotion': 'Anger'},
#  {'id': '49scDvsNT1N11yhE9weByf',
#   'name': 'Cold Night',
#   'artists': ['Yu-Peng Chen', 'HOYO-MiX'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273fd948e98a2fba6e8b22cb873',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02fd948e98a2fba6e8b22cb873',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851fd948e98a2fba6e8b22cb873',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/299fa0deebd90309df4008c660e71c62ae2fe89b?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.0337,
#   'danceability': 0.473,
#   'acousticness': 0.945,
#   'valence': 0.106,
#   'track_url': 'https://open.spotify.com/track/49scDvsNT1N11yhE9weByf',
#   'angle_deg': 229.8038747750863,
#   'quadrant': 'QUAD3',
#   'emotion': 'Sadness'},
#  {'id': '3wv4rSYfzDIZlZqeXTUW5s',
#   'name': 'Cold Nights',
#   'artists': ['Izaya Tiji'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737d18eef38bab7a2a54bd8fbb',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027d18eef38bab7a2a54bd8fbb',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517d18eef38bab7a2a54bd8fbb',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/0293043ef12cc0e183eb203890d93e8cf5684bfc?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.226,
#   'danceability': 0.556,
#   'acousticness': 0.501,
#   'valence': 0.167,
#   'track_url': 'https://open.spotify.com/track/3wv4rSYfzDIZlZqeXTUW5s',
#   'angle_deg': 219.44832769034656,
#   'quadrant': 'QUAD3',
#   'emotion': 'Sadness'},
#  {'id': '2Ybfp2mISs0UdJ5qA8Fjvz',
#   'name': 'Cold Nights',
#   'artists': ['Frontières', 'Hollow Front'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27367726aa6ab53f4a07c0c7db7',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0267726aa6ab53f4a07c0c7db7',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485167726aa6ab53f4a07c0c7db7',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/f4109c52d2c0346ff1de313bfd41b90df16c87d8?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.991,
#   'danceability': 0.468,
#   'acousticness': 0.00646,
#   'valence': 0.0545,
#   'track_url': 'https://open.spotify.com/track/2Ybfp2mISs0UdJ5qA8Fjvz',
#   'angle_deg': 132.21846277468057,
#   'quadrant': 'QUAD2',
#   'emotion': 'Anger'},
#  {'id': '0d4rt18l1E0H8nM35zivia',
#   'name': 'cold nights',
#   'artists': ['itssvd'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c0aee76a57fba419a3348fd4',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c0aee76a57fba419a3348fd4',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c0aee76a57fba419a3348fd4',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/c3c0f982d8e0b87cf5a109c213b69139455aef5a?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.155,
#   'danceability': 0.491,
#   'acousticness': 0.922,
#   'valence': 0.603,
#   'track_url': 'https://open.spotify.com/track/0d4rt18l1E0H8nM35zivia',
#   'angle_deg': 286.6230328137722,
#   'quadrant': 'QUAD4',
#   'emotion': 'Calmness'},
#  {'id': '1BumSpxYY65ZnXcwywcaGC',
#   'name': 'Cold Nights',
#   'artists': ['Seda'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273387ebe4333c745212d378c57',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02387ebe4333c745212d378c57',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851387ebe4333c745212d378c57',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/a462563f5ef5620f5306bcee5d09ef2355960943?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.981,
#   'danceability': 0.547,
#   'acousticness': 0.00491,
#   'valence': 0.505,
#   'track_url': 'https://open.spotify.com/track/1BumSpxYY65ZnXcwywcaGC',
#   'angle_deg': 89.40443122739416,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '7KFG9R3mJpzTN6TJgwqCN8',
#   'name': 'Cold Nights and Quiet Places',
#   'artists': ['Medieval Lofi'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2734cc0f56e6a7ff7de2797a8a5',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e024cc0f56e6a7ff7de2797a8a5',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048514cc0f56e6a7ff7de2797a8a5',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/6e529630d3faa5eabe8028daa54917ded8763a44?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.179,
#   'danceability': 0.818,
#   'acousticness': 0.472,
#   'valence': 0.281,
#   'track_url': 'https://open.spotify.com/track/7KFG9R3mJpzTN6TJgwqCN8',
#   'angle_deg': 235.6965107357781,
#   'quadrant': 'QUAD3',
#   'emotion': 'Sadness'},
#  {'id': '6kiXZeyy9Dcw4S5lVDw4SY',
#   'name': 'Cold Nights',
#   'artists': ['Necroez'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b7df382253b9fa3174cfa9a9',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b7df382253b9fa3174cfa9a9',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b7df382253b9fa3174cfa9a9',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/d336d0cd0c05b4793ceb947d590f84a6f6436aff?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.45,
#   'danceability': 0.808,
#   'acousticness': 0.0635,
#   'valence': 0.134,
#   'track_url': 'https://open.spotify.com/track/6kiXZeyy9Dcw4S5lVDw4SY',
#   'angle_deg': 187.77913719091435,
#   'quadrant': 'QUAD3',
#   'emotion': 'Sadness'},
#  {'id': '1iR2KYd4xQJdoVG7GICA1F',
#   'name': 'Cold Nights',
#   'artists': ['.multibeat', 'GINGE', 'Jon Ari'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2731176e8dfe52f9592fcf563ac',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e021176e8dfe52f9592fcf563ac',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048511176e8dfe52f9592fcf563ac',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/4559020c93db4ffaedce7ab9ff3891e383ac6735?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.371,
#   'danceability': 0.728,
#   'acousticness': 0.35,
#   'valence': 0.898,
#   'track_url': 'https://open.spotify.com/track/1iR2KYd4xQJdoVG7GICA1F',
#   'angle_deg': 342.04142234271086,
#   'quadrant': 'QUAD4',
#   'emotion': 'Calmness'},
#  {'id': '17ruiUWraQlUCUBcgLsJPe',
#   'name': 'Cold Nights',
#   'artists': ['Youngin42'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27307c2be9de9b81c2f3edcbda3',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0207c2be9de9b81c2f3edcbda3',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485107c2be9de9b81c2f3edcbda3',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/72a50d8a2e6dc939e979c7e120fecd953d0a4df1?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.502,
#   'danceability': 0.63,
#   'acousticness': 0.322,
#   'valence': 0.246,
#   'track_url': 'https://open.spotify.com/track/17ruiUWraQlUCUBcgLsJPe',
#   'angle_deg': 179.54886145321274,
#   'quadrant': 'QUAD2',
#   'emotion': 'Anger'},
#  {'id': '0Qct6eb2EBZUmYD5vgsqlI',
#   'name': 'Cold Nights',
#   'artists': ['FSB Beats'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735425a82367cf828f5e6758ae',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025425a82367cf828f5e6758ae',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515425a82367cf828f5e6758ae',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/5e3f54e102e67569a81e086b15ad8b8d6014b542?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.605,
#   'danceability': 0.745,
#   'acousticness': 0.00391,
#   'valence': 0.518,
#   'track_url': 'https://open.spotify.com/track/0Qct6eb2EBZUmYD5vgsqlI',
#   'angle_deg': 80.27242144859838,
#   'quadrant': 'QUAD1',
#   'emotion': 'Happiness'},
#  {'id': '4SZlM3herhL53JWEbR5rCf',
#   'name': 'Nostalgic',
#   'artists': ['Cold Night For Alligators'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27389a1cd24f621f3fe55255f0f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0289a1cd24f621f3fe55255f0f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485189a1cd24f621f3fe55255f0f',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/af10be8793b790ece00cd5c34f8257478cf57ed6?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.918,
#   'danceability': 0.467,
#   'acousticness': 2.59e-05,
#   'valence': 0.354,
#   'track_url': 'https://open.spotify.com/track/4SZlM3herhL53JWEbR5rCf',
#   'angle_deg': 109.25340428461064,
#   'quadrant': 'QUAD2',
#   'emotion': 'Anger'},
#  {'id': '5Id6O9NUfPf7tQZ3roH9Lt',
#   'name': 'Cold Nights',
#   'artists': ['Ayden.'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273d867db2c588ef2825733dd5f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02d867db2c588ef2825733dd5f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851d867db2c588ef2825733dd5f',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/3a743920f4180ce76a5123a11a74462ee010f020?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.475,
#   'danceability': 0.484,
#   'acousticness': 0.196,
#   'valence': 0.119,
#   'track_url': 'https://open.spotify.com/track/5Id6O9NUfPf7tQZ3roH9Lt',
#   'angle_deg': 183.75418379737908,
#   'quadrant': 'QUAD3',
#   'emotion': 'Sadness'},
#  {'id': '1SHSadkt2u93xvES8P2o66',
#   'name': 'Cold Nights',
#   'artists': ['Pimp Tobi'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2734bdaa267aab9584fb330d4a7',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e024bdaa267aab9584fb330d4a7',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048514bdaa267aab9584fb330d4a7',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/3cf9d4e2cd3bb01aa84362cfb6338f204b3fa67e?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.574,
#   'danceability': 0.855,
#   'acousticness': 0.0617,
#   'valence': 0.385,
#   'track_url': 'https://open.spotify.com/track/1SHSadkt2u93xvES8P2o66',
#   'angle_deg': 147.23959983693186,
#   'quadrant': 'QUAD2',
#   'emotion': 'Anger'},
#  {'id': '1bTmsrLLxnMXRTALk6QnEf',
#   'name': 'Cold Nights - BGM',
#   'artists': ['Restaurant Lounge Background Music', 'James Butler'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738fe9c5e7b57b43b41e706063',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028fe9c5e7b57b43b41e706063',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518fe9c5e7b57b43b41e706063',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/6b85a1821649d10344bf451fd09fee1755e2e16f?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.143,
#   'danceability': 0.465,
#   'acousticness': 0.942,
#   'valence': 0.252,
#   'track_url': 'https://open.spotify.com/track/1bTmsrLLxnMXRTALk6QnEf',
#   'angle_deg': 235.2131466234997,
#   'quadrant': 'QUAD3',
#   'emotion': 'Sadness'},
#  {'id': '2Xhup9HofvaMRMM0F7NUtv',
#   'name': 'Cold Nights',
#   'artists': ['frad', 'Bhxa', 'Etymology Records'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737fdb682f7fe5ca87aa627f01',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027fdb682f7fe5ca87aa627f01',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517fdb682f7fe5ca87aa627f01',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/9ce420af324925be440252b940ae929747e123c2?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.11,
#   'danceability': 0.685,
#   'acousticness': 0.749,
#   'valence': 0.179,
#   'track_url': 'https://open.spotify.com/track/2Xhup9HofvaMRMM0F7NUtv',
#   'angle_deg': 230.54299208750408,
#   'quadrant': 'QUAD3',
#   'emotion': 'Sadness'}]

# %%
i = 0

for track_info in track_info_list:
      # Increment the track number
      i += 1

      # Printing track information
      print(f"\nTrack {i}:")
      print("Track ID:", track_info['id'])
      print("Track Name:", track_info['name'])

      # Printing artists
      print("Artists:", ', '.join(track_info['artists']))

      # print track url
      print("Track URL:", track_info['track_url'])

      # Printing preview URL
      print("Preview URL:", track_info['preview_url'])

      # Printing Track Features
      print("Arousal:", track_info['arousal'])
      print("Valence:", track_info['valence'])

      # Printing Track Quadrants
      print("Angle:", track_info['angle_deg'])
      print("Quadrant:", track_info['quadrant'])
      print("Emotion:", track_info['emotion'])
# Out:
# Track 1:
# Track ID: 1bwlBQYp4KgABzsi9s7nzx
# Track Name: Cold Nights
# Artists: Hulvey
# Track URL: https://open.spotify.com/track/1bwlBQYp4KgABzsi9s7nzx
# Preview URL: https://p.scdn.co/mp3-preview/f29afc5cb3caecd897937b4f9a71dd7fe4b6e603?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.571
# Valence: 0.395
# Angle: 145.93381678575582
# Quadrant: QUAD2
# Emotion: Anger
#
# Track 2:
# Track ID: 4gKYW7JKLAO5KPwadZASPm
# Track Name: Cold Nights in Hollywood
# Artists: Buppy.
# Track URL: https://open.spotify.com/track/4gKYW7JKLAO5KPwadZASPm
# Preview URL: https://p.scdn.co/mp3-preview/05033b2d9f5ecfcfc90b658d35ea878efa6680bd?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.494
# Valence: 0.239
# Angle: 181.31691240579326
# Quadrant: QUAD3
# Emotion: Sadness
#
# Track 3:
# Track ID: 7v0mCN6KkwIuDSZJm3Tzl8
# Track Name: Cold Nights
# Artists: $tupid Young
# Track URL: https://open.spotify.com/track/7v0mCN6KkwIuDSZJm3Tzl8
# Preview URL: https://p.scdn.co/mp3-preview/1d6b48d0f954a2641960045d3556da27d9503554?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.535
# Valence: 0.27
# Angle: 171.34745820888529
# Quadrant: QUAD2
# Emotion: Anger
#
# Track 4:
# Track ID: 3OxH1yJ35RIN47bUEx3JaX
# Track Name: Cold Nights
# Artists: Pauli Gabrieli
# Track URL: https://open.spotify.com/track/3OxH1yJ35RIN47bUEx3JaX
# Preview URL: https://p.scdn.co/mp3-preview/c887a88a86effcfea31f2d9dd798fedfd1aa00aa?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.667
# Valence: 0.115
# Angle: 156.55042832784196
# Quadrant: QUAD2
# Emotion: Anger
#
# Track 5:
# Track ID: 49scDvsNT1N11yhE9weByf
# Track Name: Cold Night
# Artists: Yu-Peng Chen, HOYO-MiX
# Track URL: https://open.spotify.com/track/49scDvsNT1N11yhE9weByf
# Preview URL: https://p.scdn.co/mp3-preview/299fa0deebd90309df4008c660e71c62ae2fe89b?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.0337
# Valence: 0.106
# Angle: 229.8038747750863
# Quadrant: QUAD3
# Emotion: Sadness
#
# Track 6:
# Track ID: 3wv4rSYfzDIZlZqeXTUW5s
# Track Name: Cold Nights
# Artists: Izaya Tiji
# Track URL: https://open.spotify.com/track/3wv4rSYfzDIZlZqeXTUW5s
# Preview URL: https://p.scdn.co/mp3-preview/0293043ef12cc0e183eb203890d93e8cf5684bfc?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.226
# Valence: 0.167
# Angle: 219.44832769034656
# Quadrant: QUAD3
# Emotion: Sadness
#
# Track 7:
# Track ID: 2Ybfp2mISs0UdJ5qA8Fjvz
# Track Name: Cold Nights
# Artists: Frontières, Hollow Front
# Track URL: https://open.spotify.com/track/2Ybfp2mISs0UdJ5qA8Fjvz
# Preview URL: https://p.scdn.co/mp3-preview/f4109c52d2c0346ff1de313bfd41b90df16c87d8?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.991
# Valence: 0.0545
# Angle: 132.21846277468057
# Quadrant: QUAD2
# Emotion: Anger
#
# Track 8:
# Track ID: 0d4rt18l1E0H8nM35zivia
# Track Name: cold nights
# Artists: itssvd
# Track URL: https://open.spotify.com/track/0d4rt18l1E0H8nM35zivia
# Preview URL: https://p.scdn.co/mp3-preview/c3c0f982d8e0b87cf5a109c213b69139455aef5a?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.155
# Valence: 0.603
# Angle: 286.6230328137722
# Quadrant: QUAD4
# Emotion: Calmness
#
# Track 9:
# Track ID: 1BumSpxYY65ZnXcwywcaGC
# Track Name: Cold Nights
# Artists: Seda
# Track URL: https://open.spotify.com/track/1BumSpxYY65ZnXcwywcaGC
# Preview URL: https://p.scdn.co/mp3-preview/a462563f5ef5620f5306bcee5d09ef2355960943?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.981
# Valence: 0.505
# Angle: 89.40443122739416
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 10:
# Track ID: 7KFG9R3mJpzTN6TJgwqCN8
# Track Name: Cold Nights and Quiet Places
# Artists: Medieval Lofi
# Track URL: https://open.spotify.com/track/7KFG9R3mJpzTN6TJgwqCN8
# Preview URL: https://p.scdn.co/mp3-preview/6e529630d3faa5eabe8028daa54917ded8763a44?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.179
# Valence: 0.281
# Angle: 235.6965107357781
# Quadrant: QUAD3
# Emotion: Sadness
#
# Track 11:
# Track ID: 6kiXZeyy9Dcw4S5lVDw4SY
# Track Name: Cold Nights
# Artists: Necroez
# Track URL: https://open.spotify.com/track/6kiXZeyy9Dcw4S5lVDw4SY
# Preview URL: https://p.scdn.co/mp3-preview/d336d0cd0c05b4793ceb947d590f84a6f6436aff?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.45
# Valence: 0.134
# Angle: 187.77913719091435
# Quadrant: QUAD3
# Emotion: Sadness
#
# Track 12:
# Track ID: 1iR2KYd4xQJdoVG7GICA1F
# Track Name: Cold Nights
# Artists: .multibeat, GINGE, Jon Ari
# Track URL: https://open.spotify.com/track/1iR2KYd4xQJdoVG7GICA1F
# Preview URL: https://p.scdn.co/mp3-preview/4559020c93db4ffaedce7ab9ff3891e383ac6735?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.371
# Valence: 0.898
# Angle: 342.04142234271086
# Quadrant: QUAD4
# Emotion: Calmness
#
# Track 13:
# Track ID: 17ruiUWraQlUCUBcgLsJPe
# Track Name: Cold Nights
# Artists: Youngin42
# Track URL: https://open.spotify.com/track/17ruiUWraQlUCUBcgLsJPe
# Preview URL: https://p.scdn.co/mp3-preview/72a50d8a2e6dc939e979c7e120fecd953d0a4df1?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.502
# Valence: 0.246
# Angle: 179.54886145321274
# Quadrant: QUAD2
# Emotion: Anger
#
# Track 14:
# Track ID: 0Qct6eb2EBZUmYD5vgsqlI
# Track Name: Cold Nights
# Artists: FSB Beats
# Track URL: https://open.spotify.com/track/0Qct6eb2EBZUmYD5vgsqlI
# Preview URL: https://p.scdn.co/mp3-preview/5e3f54e102e67569a81e086b15ad8b8d6014b542?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.605
# Valence: 0.518
# Angle: 80.27242144859838
# Quadrant: QUAD1
# Emotion: Happiness
#
# Track 15:
# Track ID: 4SZlM3herhL53JWEbR5rCf
# Track Name: Nostalgic
# Artists: Cold Night For Alligators
# Track URL: https://open.spotify.com/track/4SZlM3herhL53JWEbR5rCf
# Preview URL: https://p.scdn.co/mp3-preview/af10be8793b790ece00cd5c34f8257478cf57ed6?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.918
# Valence: 0.354
# Angle: 109.25340428461064
# Quadrant: QUAD2
# Emotion: Anger
#
# Track 16:
# Track ID: 5Id6O9NUfPf7tQZ3roH9Lt
# Track Name: Cold Nights
# Artists: Ayden.
# Track URL: https://open.spotify.com/track/5Id6O9NUfPf7tQZ3roH9Lt
# Preview URL: https://p.scdn.co/mp3-preview/3a743920f4180ce76a5123a11a74462ee010f020?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.475
# Valence: 0.119
# Angle: 183.75418379737908
# Quadrant: QUAD3
# Emotion: Sadness
#
# Track 17:
# Track ID: 1SHSadkt2u93xvES8P2o66
# Track Name: Cold Nights
# Artists: Pimp Tobi
# Track URL: https://open.spotify.com/track/1SHSadkt2u93xvES8P2o66
# Preview URL: https://p.scdn.co/mp3-preview/3cf9d4e2cd3bb01aa84362cfb6338f204b3fa67e?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.574
# Valence: 0.385
# Angle: 147.23959983693186
# Quadrant: QUAD2
# Emotion: Anger
#
# Track 18:
# Track ID: 1bTmsrLLxnMXRTALk6QnEf
# Track Name: Cold Nights - BGM
# Artists: Restaurant Lounge Background Music, James Butler
# Track URL: https://open.spotify.com/track/1bTmsrLLxnMXRTALk6QnEf
# Preview URL: https://p.scdn.co/mp3-preview/6b85a1821649d10344bf451fd09fee1755e2e16f?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.143
# Valence: 0.252
# Angle: 235.2131466234997
# Quadrant: QUAD3
# Emotion: Sadness
#
# Track 19:
# Track ID: 2Xhup9HofvaMRMM0F7NUtv
# Track Name: Cold Nights
# Artists: frad, Bhxa, Etymology Records
# Track URL: https://open.spotify.com/track/2Xhup9HofvaMRMM0F7NUtv
# Preview URL: https://p.scdn.co/mp3-preview/9ce420af324925be440252b940ae929747e123c2?cid=7a5ccd9e742a4adc9e73041d836087be
# Arousal: 0.11
# Valence: 0.179
# Angle: 230.54299208750408
# Quadrant: QUAD3
# Emotion: Sadness

# %% [markdown]
# - Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# - Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.

# %% [markdown]
# 1. If you're interested in the physical aspect of arousal related to movement and rhythm, danceability might be more suitable.
# 2. If you're interested in a broader sense of arousal including emotional intensity, energy could be more appropriate.

# %%
your_predicted_emotion = "Anger"

# %%
# Filter tracks by predicted emotion
filtered_tracks = [track for track in track_info_list if track['emotion'] == your_predicted_emotion]

# If the length of filtered_tracks is less than 5, include tracks with other emotions
if len(filtered_tracks) < 5:
  other_tracks = [track for track in track_info_list if track['emotion'] != your_predicted_emotion]
  filtered_tracks += other_tracks[:5 - len(filtered_tracks)]

# Sort tracks by their angle_deg
filtered_tracks.sort(key=lambda track: track['angle_deg'])

# Calculate the mean of angles in filtered tracks using NumPy
mean_angle = np.mean([track['angle_deg'] for track in filtered_tracks])

# Sort tracks by their angle difference from the mean angle using NumPy
sorted_indices = np.argsort(np.abs([track['angle_deg'] - mean_angle for track in filtered_tracks]))

# Get the top 5 tracks with angles closest to the mean angle
top_5_tracks = [filtered_tracks[i] for i in sorted_indices[:5]]

top_5_tracks
# Out:
# [{'id': '1SHSadkt2u93xvES8P2o66',
#   'name': 'Cold Nights',
#   'artists': ['Pimp Tobi'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2734bdaa267aab9584fb330d4a7',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e024bdaa267aab9584fb330d4a7',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048514bdaa267aab9584fb330d4a7',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/3cf9d4e2cd3bb01aa84362cfb6338f204b3fa67e?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.574,
#   'danceability': 0.855,
#   'acousticness': 0.0617,
#   'valence': 0.385,
#   'track_url': 'https://open.spotify.com/track/1SHSadkt2u93xvES8P2o66',
#   'angle_deg': 147.23959983693186,
#   'quadrant': 'QUAD2',
#   'emotion': 'Anger'},
#  {'id': '1bwlBQYp4KgABzsi9s7nzx',
#   'name': 'Cold Nights',
#   'artists': ['Hulvey'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2733aaaeab5117e8b8f776596cb',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e023aaaeab5117e8b8f776596cb',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048513aaaeab5117e8b8f776596cb',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/f29afc5cb3caecd897937b4f9a71dd7fe4b6e603?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.571,
#   'danceability': 0.762,
#   'acousticness': 0.0342,
#   'valence': 0.395,
#   'track_url': 'https://open.spotify.com/track/1bwlBQYp4KgABzsi9s7nzx',
#   'angle_deg': 145.93381678575582,
#   'quadrant': 'QUAD2',
#   'emotion': 'Anger'},
#  {'id': '3OxH1yJ35RIN47bUEx3JaX',
#   'name': 'Cold Nights',
#   'artists': ['Pauli Gabrieli'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e5f13965ebbca3362c48b3a5',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e5f13965ebbca3362c48b3a5',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e5f13965ebbca3362c48b3a5',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/c887a88a86effcfea31f2d9dd798fedfd1aa00aa?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.667,
#   'danceability': 0.837,
#   'acousticness': 0.0211,
#   'valence': 0.115,
#   'track_url': 'https://open.spotify.com/track/3OxH1yJ35RIN47bUEx3JaX',
#   'angle_deg': 156.55042832784196,
#   'quadrant': 'QUAD2',
#   'emotion': 'Anger'},
#  {'id': '2Ybfp2mISs0UdJ5qA8Fjvz',
#   'name': 'Cold Nights',
#   'artists': ['Frontières', 'Hollow Front'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27367726aa6ab53f4a07c0c7db7',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0267726aa6ab53f4a07c0c7db7',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485167726aa6ab53f4a07c0c7db7',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/f4109c52d2c0346ff1de313bfd41b90df16c87d8?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.991,
#   'danceability': 0.468,
#   'acousticness': 0.00646,
#   'valence': 0.0545,
#   'track_url': 'https://open.spotify.com/track/2Ybfp2mISs0UdJ5qA8Fjvz',
#   'angle_deg': 132.21846277468057,
#   'quadrant': 'QUAD2',
#   'emotion': 'Anger'},
#  {'id': '7v0mCN6KkwIuDSZJm3Tzl8',
#   'name': 'Cold Nights',
#   'artists': ['$tupid Young'],
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273fcc462398eda5bae81d29066',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02fcc462398eda5bae81d29066',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851fcc462398eda5bae81d29066',
#     'width': 64}],
#   'preview_url': 'https://p.scdn.co/mp3-preview/1d6b48d0f954a2641960045d3556da27d9503554?cid=7a5ccd9e742a4adc9e73041d836087be',
#   'arousal': 0.535,
#   'danceability': 0.774,
#   'acousticness': 0.384,
#   'valence': 0.27,
#   'track_url': 'https://open.spotify.com/track/7v0mCN6KkwIuDSZJm3Tzl8',
#   'angle_deg': 171.34745820888529,
#   'quadrant': 'QUAD2',
#   'emotion': 'Anger'}]

# %% [markdown]
# # DF Visualization

# %%
import pandas as pd

df = pd.DataFrame(top_5_tracks)

# %%
df.drop(columns=['images'], inplace=True)

# %%
df
# Out:
#                        id         name                     artists  \
# 0  1SHSadkt2u93xvES8P2o66  Cold Nights                 [Pimp Tobi]
# 1  1bwlBQYp4KgABzsi9s7nzx  Cold Nights                    [Hulvey]
# 2  3OxH1yJ35RIN47bUEx3JaX  Cold Nights            [Pauli Gabrieli]
# 3  2Ybfp2mISs0UdJ5qA8Fjvz  Cold Nights  [Frontières, Hollow Front]
# 4  7v0mCN6KkwIuDSZJm3Tzl8  Cold Nights              [$tupid Young]
#
#                                          preview_url  arousal  danceability  \
# 0  https://p.scdn.co/mp3-preview/3cf9d4e2cd3bb01a...    0.574         0.855
# 1  https://p.scdn.co/mp3-preview/f29afc5cb3caecd8...    0.571         0.762
# 2  https://p.scdn.co/mp3-preview/c887a88a86effcfe...    0.667         0.837
# 3  https://p.scdn.co/mp3-preview/f4109c52d2c0346f...    0.991         0.468
# 4  https://p.scdn.co/mp3-preview/1d6b48d0f954a264...    0.535         0.774
#
#    acousticness  valence                                          track_url  \
# 0       0.06170   0.3850  https://open.spotify.com/track/1SHSadkt2u93xvE...
# 1       0.03420   0.3950  https://open.spotify.com/track/1bwlBQYp4KgABzs...
# 2       0.02110   0.1150  https://open.spotify.com/track/3OxH1yJ35RIN47b...
# 3       0.00646   0.0545  https://open.spotify.com/track/2Ybfp2mISs0UdJ5...
# 4       0.38400   0.2700  https://open.spotify.com/track/7v0mCN6KkwIuDSZ...
#
#     angle_deg quadrant emotion
# 0  147.239600    QUAD2   Anger
# 1  145.933817    QUAD2   Anger
# 2  156.550428    QUAD2   Anger
# 3  132.218463    QUAD2   Anger
# 4  171.347458    QUAD2   Anger
